# %% [markdown]
# # Symbolic Calculation of Full Jacobian

# %%
from sympy import *
import numpy as np
init_printing(use_unicode=True)

# %%
def dh_transform(a, alpha, d, theta):
    return Matrix([
        [cos(theta), -sin(theta)*cos(alpha), sin(theta)*sin(alpha), a*cos(theta)],
        [sin(theta), cos(theta)*cos(alpha), -cos(theta)*sin(alpha), a*sin(theta)],
        [0, sin(alpha), cos(alpha), d],
        [0, 0, 0, 1]
    ])

def rotation_to_euler(R):
    yaw = atan2(R[1, 0], R[0, 0])
    pitch = atan2(-R[2, 0], sqrt(R[2, 1]**2 + R[2, 2]**2))
    roll = atan2(R[2, 1], R[2, 2])
    return Matrix([yaw, pitch, roll])

# %%
# Define symbolic joint angles
theta = symbols('theta1:7')

l1, l2, h1, h2, w, h3, h4, o = symbols('l1, l2, h1, h2, w, h3, h4, o')

dh_params = [
    (0, pi/2, h1, theta[0]),
    (l1, 0, 0, theta[1] + pi/2),
    (h2, pi/2, 0, theta[2] + pi/2),
    (0, -pi/2, l2 + h3, theta[3]),
    (0, pi/2, h4, theta[4]),
    (0, 0, o, theta[5])
]

# Compute forward kinematics
T = eye(4)
for params in dh_params:
    transform = simplify(dh_transform(*params))
    pprint(transform)
    T *= transform
    simplify(T)

pprint(T)
# Out:
# ⎡cos(θ₁)  0  sin(θ₁)   0 ⎤
# ⎢                        ⎥
# ⎢sin(θ₁)  0  -cos(θ₁)  0 ⎥
# ⎢                        ⎥
# ⎢   0     1     0      h₁⎥
# ⎢                        ⎥
# ⎣   0     0     0      1 ⎦
# ⎡-sin(θ₂)  -cos(θ₂)  0  -l₁⋅sin(θ₂)⎤
# ⎢                                  ⎥
# ⎢cos(θ₂)   -sin(θ₂)  0  l₁⋅cos(θ₂) ⎥
# ⎢                                  ⎥
# ⎢   0         0      1       0     ⎥
# ⎢                                  ⎥
# ⎣   0         0      0       1     ⎦
# ⎡-sin(θ₃)  0  cos(θ₃)  -h₂⋅sin(θ₃)⎤
# ⎢                                 ⎥
# ⎢cos(θ₃)   0  sin(θ₃)  h₂⋅cos(θ₃) ⎥
# ⎢                                 ⎥
# ⎢   0      1     0          0     ⎥
# ⎢                                 ⎥
# ⎣   0      0     0          1     ⎦
# ⎡cos(θ₄)  0   -sin(θ₄)     0   ⎤
# ⎢                              ⎥
# ⎢sin(θ₄)  0   cos(θ₄)      0   ⎥
# ⎢                              ⎥
# ⎢   0     -1     0      h₃ + l₂⎥
# ⎢                              ⎥
# ⎣   0     0      0         1   ⎦
# ⎡cos(θ₅)  0  sin(θ₅)   0 ⎤
# ⎢                        ⎥
# ⎢sin(θ₅)  0  -cos(θ₅)  0 ⎥
# ⎢                        ⎥
# ⎢   0     1     0      h₄⎥
# ⎢                        ⎥
# ⎣   0     0     0      1 ⎦
# ⎡cos(θ₆)  -sin(θ₆)  0  0⎤
# ⎢                       ⎥
# ⎢sin(θ₆)  cos(θ₆)   0  0⎥
# ⎢                       ⎥
# ⎢   0        0      1  o⎥
# ⎢                       ⎥
# ⎣   0        0      0  1⎦
# ⎡(((sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) - cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ
# ⎢
# ⎢(((sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) - sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ
# ⎢
# ⎢                                           ((sin(θ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ₃
# ⎢
# ⎣
#
# ₄))⋅cos(θ₅) + (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₅))⋅cos
#
# ₁))⋅cos(θ₅) + (sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₅))⋅cos
#
# ))⋅sin(θ₅) + (-sin(θ₂)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₂))⋅cos(θ₄)⋅cos(θ₅))⋅cos(θ₆) - (
#
#                                                0
#
# (θ₆) + (-(sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) - cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(θ₁)
#
# (θ₆) + (-(sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) - sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - cos(θ₁)
#
# -sin(θ₂)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₂))⋅sin(θ₄)⋅sin(θ₆)
#
#
#
# ⋅cos(θ₄))⋅sin(θ₆)  -(((sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) - cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(
#
# ⋅cos(θ₄))⋅sin(θ₆)  -(((sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) - sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(
#
#                                                               -((sin(θ₂)⋅sin(θ
#
#
#
# θ₄) + sin(θ₁)⋅sin(θ₄))⋅cos(θ₅) + (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅co
#
# θ₄) - sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) + (sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅co
#
# ₃) - cos(θ₂)⋅cos(θ₃))⋅sin(θ₅) + (-sin(θ₂)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₂))⋅cos(θ₄)⋅c
#
#                                                                   0
#
# s(θ₂))⋅sin(θ₅))⋅sin(θ₆) + (-(sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) - cos(θ₁)⋅cos(θ₂)⋅cos(θ₃)
#
# s(θ₂))⋅sin(θ₅))⋅sin(θ₆) + (-(sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) - sin(θ₁)⋅cos(θ₂)⋅cos(θ₃)
#
# os(θ₅))⋅sin(θ₆) - (-sin(θ₂)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₂))⋅sin(θ₄)⋅cos(θ₆)
#
#
#
# )⋅sin(θ₄) + sin(θ₁)⋅cos(θ₄))⋅cos(θ₆)  ((sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) - cos(θ₁)⋅cos(
#
# )⋅sin(θ₄) - cos(θ₁)⋅cos(θ₄))⋅cos(θ₆)  ((sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) - sin(θ₁)⋅cos(
#
#                                                                -(sin(θ₂)⋅sin(θ
#
#
#
# θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅sin(θ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + s
#
# θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅sin(θ₅) - (sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + s
#
# ₃) - cos(θ₂)⋅cos(θ₃))⋅cos(θ₅) + (-sin(θ₂)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₂))⋅sin(θ₅)⋅c
#
#                                   0
#
# in(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅cos(θ₅)  h₂⋅sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) - h₂⋅cos(θ₁)⋅cos(θ
#
# in(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₅)  h₂⋅sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) - h₂⋅sin(θ₁)⋅cos(θ
#
# os(θ₄)
#
#
#
# ₂)⋅cos(θ₃) + h₄⋅(-(sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) - cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄)
#
# ₂)⋅cos(θ₃) + h₄⋅(-(sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) - sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄)
#
#                h₁ - h₂⋅sin(θ₂)⋅cos(θ₃) - h₂⋅sin(θ₃)⋅cos(θ₂) - h₄⋅(-sin(θ₂)⋅cos
#
#
#
# + sin(θ₁)⋅cos(θ₄)) - l₁⋅sin(θ₂)⋅cos(θ₁) + o⋅(((sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) - cos(θ
#
# - cos(θ₁)⋅cos(θ₄)) - l₁⋅sin(θ₁)⋅sin(θ₂) + o⋅(((sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) - sin(θ
#
# (θ₃) - sin(θ₃)⋅cos(θ₂))⋅sin(θ₄) + l₁⋅cos(θ₂) + o⋅(-(sin(θ₂)⋅sin(θ₃) - cos(θ₂)⋅
#
#                                                                     1
#
# ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅sin(θ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos(
#
# ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅sin(θ₅) - (sin(θ₁)⋅sin(θ₂)⋅cos(
#
# cos(θ₃))⋅cos(θ₅) + (-sin(θ₂)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₂))⋅sin(θ₅)⋅cos(θ₄)) + (h₃
#
#
#
# θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅cos(θ₅)) + (h₃ + l₂)⋅(-sin(θ₂)⋅cos(θ₁)⋅cos(θ₃)
#
# θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₅)) + (h₃ + l₂)⋅(-sin(θ₁)⋅sin(θ₂)⋅cos(θ₃)
#
#  + l₂)⋅(-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃))
#
#
#
# - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⎤
#                           ⎥
# - sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⎥
#                           ⎥
#                           ⎥
#                           ⎥
#                           ⎦

# %%
# Extract end-effector position and orientation
position = T[:3, 3]
R = T[:3, :3]



euler_angles = rotation_to_euler(R)

# Compute the Jacobian
pose = simplify(Matrix.vstack(position, euler_angles))

pprint(pose)
# Out:
# ⎡                                  -h₂⋅cos(θ₁)⋅cos(θ₂ + θ₃) - h₃⋅sin(θ₂ + θ₃)⋅
# ⎢
# ⎢                                  -h₂⋅sin(θ₁)⋅cos(θ₂ + θ₃) - h₃⋅sin(θ₁)⋅sin(θ
# ⎢
# ⎢
# ⎢
# ⎢atan2((-(sin(θ₁)⋅cos(θ₄)⋅cos(θ₂ + θ₃) + sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) + sin(θ₁)⋅si
# ⎢
# ⎢                                     ⎛
# ⎢                                     ⎜
# ⎢                                atan2⎝(sin(θ₅)⋅cos(θ₂ + θ₃) + sin(θ₂ + θ₃)⋅co
# ⎢
# ⎣
#
# cos(θ₁) + h₄⋅sin(θ₁)⋅cos(θ₄) + h₄⋅sin(θ₄)⋅cos(θ₁)⋅cos(θ₂ + θ₃) - l₁⋅sin(θ₂)⋅co
#
# ₂ + θ₃) + h₄⋅sin(θ₁)⋅sin(θ₄)⋅cos(θ₂ + θ₃) - h₄⋅cos(θ₁)⋅cos(θ₄) - l₁⋅sin(θ₁)⋅si
#
#         h₁ - h₂⋅sin(θ₂ + θ₃) + h₃⋅cos(θ₂ + θ₃) + h₄⋅sin(θ₄)⋅sin(θ₂ + θ₃) + l₁⋅
#
# n(θ₅)⋅sin(θ₂ + θ₃))⋅cos(θ₆) - (-sin(θ₁)⋅sin(θ₄)⋅cos(θ₂ + θ₃) + cos(θ₁)⋅cos(θ₄)
#
#                                                           ____________________
#                                                          ╱
# s(θ₄)⋅cos(θ₅))⋅cos(θ₆) - sin(θ₄)⋅sin(θ₆)⋅sin(θ₂ + θ₃), ╲╱  ((sin(θ₅)⋅cos(θ₂ +
#
#         atan2((sin(θ₅)⋅cos(θ₂ + θ₃) + sin(θ₂ + θ₃)⋅cos(θ₄)⋅cos(θ₅))⋅sin(θ₆) +
#
# s(θ₁) - l₂⋅sin(θ₂ + θ₃)⋅cos(θ₁) + o⋅sin(θ₁)⋅sin(θ₄)⋅sin(θ₅) - o⋅sin(θ₅)⋅cos(θ₁
#
# n(θ₂) - l₂⋅sin(θ₁)⋅sin(θ₂ + θ₃) - o⋅sin(θ₁)⋅sin(θ₅)⋅cos(θ₄)⋅cos(θ₂ + θ₃) - o⋅s
#
# cos(θ₂) + l₂⋅cos(θ₂ + θ₃) - o⋅sin(θ₅)⋅sin(θ₂ + θ₃)⋅cos(θ₄) + o⋅cos(θ₅)⋅cos(θ₂
#
# )⋅sin(θ₆), ((sin(θ₁)⋅sin(θ₄) - cos(θ₁)⋅cos(θ₄)⋅cos(θ₂ + θ₃))⋅cos(θ₅) + sin(θ₅)
#
# ______________________________________________________________________________
#                                                                            2
# θ₃) + sin(θ₂ + θ₃)⋅cos(θ₄)⋅cos(θ₅))⋅sin(θ₆) + sin(θ₄)⋅sin(θ₂ + θ₃)⋅cos(θ₆))  +
#
# sin(θ₄)⋅sin(θ₂ + θ₃)⋅cos(θ₆), -sin(θ₅)⋅sin(θ₂ + θ₃)⋅cos(θ₄) + cos(θ₅)⋅cos(θ₂ +
#
# )⋅cos(θ₄)⋅cos(θ₂ + θ₃) - o⋅sin(θ₂ + θ₃)⋅cos(θ₁)⋅cos(θ₅)
#
# in(θ₁)⋅sin(θ₂ + θ₃)⋅cos(θ₅) - o⋅sin(θ₄)⋅sin(θ₅)⋅cos(θ₁)
#
# + θ₃)
#
# ⋅sin(θ₂ + θ₃)⋅cos(θ₁))⋅cos(θ₆) + (sin(θ₁)⋅cos(θ₄) + sin(θ₄)⋅cos(θ₁)⋅cos(θ₂ + θ
#
# ________________________________________________________⎞
#                                                       2 ⎟
#  (sin(θ₅)⋅sin(θ₂ + θ₃)⋅cos(θ₄) - cos(θ₅)⋅cos(θ₂ + θ₃))  ⎠
#
#  θ₃))
#
#             ⎤
#             ⎥
#             ⎥
#             ⎥
#             ⎥
#             ⎥
# ₃))⋅sin(θ₆))⎥
#             ⎥
#             ⎥
#             ⎥
#             ⎥
#             ⎥
#             ⎦

# %%
J = simplify(pose.jacobian(theta))

# pprint(pose)

with open("jacobian2.tex", "w") as f:
    f.write(latex(J))

# %% [markdown]
# # Partial IK Decomposition (3DOF and Spherical Wrist)

# %%
from sympy import *
import numpy as np
# init_printing(use_unicode=True)
init_printing()

# %%
def dh_transform(a, alpha, d, theta):
    return Matrix([
        [cos(theta), -sin(theta)*cos(alpha), sin(theta)*sin(alpha), a*cos(theta)],
        [sin(theta), cos(theta)*cos(alpha), -cos(theta)*sin(alpha), a*sin(theta)],
        [0, sin(alpha), cos(alpha), d],
        [0, 0, 0, 1]
    ])

def rotation_to_euler(R):
    yaw = atan2(R[1, 0], R[0, 0])
    pitch = atan2(-R[2, 0], sqrt(R[2, 1]**2 + R[2, 2]**2))
    roll = atan2(R[2, 1], R[2, 2])
    return Matrix([yaw, pitch, roll])

# %%
# Define symbolic joint angles
theta = symbols('theta1:7')

"""
l1: length of first arm
l2: length of second arm
h1: height from base of shoulder motor
h2: offset of second arm (it is L shaped)
h3: offset of spherical wrist center
h4: height of motor (dist from center of spherical wrist to end effector)
"""
l1, l2, h1, h2, h3, h4 = symbols('l1, l2, h1, h2, h3, h4')

dh_params = [
    [0, pi/2, h1, theta[0]], # Joint 1 (base rotation)
    [l1, 0, 0, theta[1] + pi/2], # Joint 2 (shoulder)
    [h2, pi/2, 0, -theta[2] + pi/2], # Joint 3 (elbow)
    [0, -pi/2, l2 + h3, theta[3]], # Joint 4 (wrist 1)
    [0, -pi/2, 0, theta[4]], # Joint 5 (wrist 2)
    [0, 0, h4, theta[5]] # Joint 6 (wrist 3)
]

# Compute forward kinematics
T = eye(4)
for params in dh_params[:4]: # use up to joint 4 for wrist location
    transform = simplify(dh_transform(*params))
    pprint(transform)
    T *= transform
    simplify(T)

pprint(T)
# Out:
# ⎡cos(θ₁)  0  sin(θ₁)   0 ⎤
# ⎢                        ⎥
# ⎢sin(θ₁)  0  -cos(θ₁)  0 ⎥
# ⎢                        ⎥
# ⎢   0     1     0      h₁⎥
# ⎢                        ⎥
# ⎣   0     0     0      1 ⎦
# ⎡-sin(θ₂)  -cos(θ₂)  0  -l₁⋅sin(θ₂)⎤
# ⎢                                  ⎥
# ⎢cos(θ₂)   -sin(θ₂)  0  l₁⋅cos(θ₂) ⎥
# ⎢                                  ⎥
# ⎢   0         0      1       0     ⎥
# ⎢                                  ⎥
# ⎣   0         0      0       1     ⎦
# ⎡sin(θ₃)  0  cos(θ₃)   h₂⋅sin(θ₃)⎤
# ⎢                                ⎥
# ⎢cos(θ₃)  0  -sin(θ₃)  h₂⋅cos(θ₃)⎥
# ⎢                                ⎥
# ⎢   0     1     0          0     ⎥
# ⎢                                ⎥
# ⎣   0     0     0          1     ⎦
# ⎡cos(θ₄)  0   -sin(θ₄)     0   ⎤
# ⎢                              ⎥
# ⎢sin(θ₄)  0   cos(θ₄)      0   ⎥
# ⎢                              ⎥
# ⎢   0     -1     0      h₃ + l₂⎥
# ⎢                              ⎥
# ⎣   0     0      0         1   ⎦
# ⎡(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) - cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄
# ⎢
# ⎢(-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) - sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁
# ⎢
# ⎢                 (-sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅cos(θ₄)
# ⎢
# ⎣                                      0
#
# )  sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂)  -(-sin(θ₂)⋅sin(θ₃)⋅cos(θ
#
# )  sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) - sin(θ₁)⋅sin(θ₃)⋅cos(θ₂)  -(-sin(θ₁)⋅sin(θ₂)⋅sin(θ
#
#           -sin(θ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ₃)                           -(-sin(
#
#                            0
#
# ₁) - cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(θ₁)⋅cos(θ₄)  -h₂⋅sin(θ₂)⋅sin(θ₃)⋅c
#
# ₃) - sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - cos(θ₁)⋅cos(θ₄)  -h₂⋅sin(θ₁)⋅sin(θ₂)⋅s
#
# θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅sin(θ₄)                                     h₁
#
#                0
#
# os(θ₁) - h₂⋅cos(θ₁)⋅cos(θ₂)⋅cos(θ₃) - l₁⋅sin(θ₂)⋅cos(θ₁) + (h₃ + l₂)⋅(-sin(θ₂)
#
# in(θ₃) - h₂⋅sin(θ₁)⋅cos(θ₂)⋅cos(θ₃) - l₁⋅sin(θ₁)⋅sin(θ₂) + (h₃ + l₂)⋅(-sin(θ₁)
#
# - h₂⋅sin(θ₂)⋅cos(θ₃) + h₂⋅sin(θ₃)⋅cos(θ₂) + l₁⋅cos(θ₂) + (h₃ + l₂)⋅(sin(θ₂)⋅si
#
#                                                  1
#
# ⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⎤
#                                            ⎥
# ⋅sin(θ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⎥
#                                            ⎥
# n(θ₃) + cos(θ₂)⋅cos(θ₃))                   ⎥
#                                            ⎥
#                                            ⎦

# %%
position = simplify(T[:3, 3])

pprint(position)
# Out:
# ⎡-(h₂⋅cos(θ₂ - θ₃) + h₃⋅sin(θ₂ - θ₃) + l₁⋅sin(θ₂) + l₂⋅sin(θ₂ - θ₃))⋅cos(θ₁)⎤
# ⎢                                                                           ⎥
# ⎢-(h₂⋅cos(θ₂ - θ₃) + h₃⋅sin(θ₂ - θ₃) + l₁⋅sin(θ₂) + l₂⋅sin(θ₂ - θ₃))⋅sin(θ₁)⎥
# ⎢                                                                           ⎥
# ⎣   h₁ - h₂⋅sin(θ₂ - θ₃) + h₃⋅cos(θ₂ - θ₃) + l₁⋅cos(θ₂) + l₂⋅cos(θ₂ - θ₃)   ⎦

# %%
J = simplify(position.jacobian(theta))

with open("jacobian_3dof.tex", "w") as f:
    f.write(latex(J))

# %%
for i in range(3):
    for j in range (3):
        print(f"J{i+1}{j+1} = ", end='')
        pprint(J[i, j])
# Out:
# J11 = (h₂⋅cos(θ₂ - θ₃) + h₃⋅sin(θ₂ - θ₃) + l₁⋅sin(θ₂) + l₂⋅sin(θ₂ - θ₃))⋅sin(θ₁)
# J12 = (h₂⋅sin(θ₂ - θ₃) - h₃⋅cos(θ₂ - θ₃) - l₁⋅cos(θ₂) - l₂⋅cos(θ₂ - θ₃))⋅cos(θ₁)
# J13 = (-h₂⋅sin(θ₂ - θ₃) + h₃⋅cos(θ₂ - θ₃) + l₂⋅cos(θ₂ - θ₃))⋅cos(θ₁)
# J21 = -(h₂⋅cos(θ₂ - θ₃) + h₃⋅sin(θ₂ - θ₃) + l₁⋅sin(θ₂) + l₂⋅sin(θ₂ - θ₃))⋅cos(θ₁)
# J22 = (h₂⋅sin(θ₂ - θ₃) - h₃⋅cos(θ₂ - θ₃) - l₁⋅cos(θ₂) - l₂⋅cos(θ₂ - θ₃))⋅sin(θ₁)
# J23 = (-h₂⋅sin(θ₂ - θ₃) + h₃⋅cos(θ₂ - θ₃) + l₂⋅cos(θ₂ - θ₃))⋅sin(θ₁)
# J31 = 0
# J32 = -h₂⋅cos(θ₂ - θ₃) - h₃⋅sin(θ₂ - θ₃) - l₁⋅sin(θ₂) - l₂⋅sin(θ₂ - θ₃)
# J33 = h₂⋅cos(θ₂ - θ₃) + h₃⋅sin(θ₂ - θ₃) + l₂⋅sin(θ₂ - θ₃)
